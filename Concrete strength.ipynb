# %%
cd C:\Users\PRASANT\Desktop\Data Science\Datasets
# Out:
# C:\Users\PRASANT\Desktop\Data Science\Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('concrete_data.csv')
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
df.corr()
# Out:
#                       Cement  Blast Furnace Slag   Fly Ash     Water  \
# Cement              1.000000           -0.275216 -0.397467 -0.081587
# Blast Furnace Slag -0.275216            1.000000 -0.323580  0.107252
# Fly Ash            -0.397467           -0.323580  1.000000 -0.256984
# Water              -0.081587            0.107252 -0.256984  1.000000
# Superplasticizer    0.092386            0.043270  0.377503 -0.657533
# Coarse Aggregate   -0.109349           -0.283999 -0.009961 -0.182294
# Fine Aggregate     -0.222718           -0.281603  0.079108 -0.450661
# Age                 0.081946           -0.044246 -0.154371  0.277618
# Strength            0.497832            0.134829 -0.105755 -0.289633
#
#                     Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# Cement                      0.092386         -0.109349       -0.222718
# Blast Furnace Slag          0.043270         -0.283999       -0.281603
# ...

# %%
fig,axes= plt.subplots(nrows=1,ncols=8,figsize=(16,6))

axes[0].plot(df['Cement'],df['Strength'])
axes[0].set_ylabel('Strength')
axes[0].set_title('Impact of cement')

axes[1].plot(df['Blast Furnace Slag'],df['Strength'])
axes[1].set_ylabel('Strength')
axes[1].set_title('Impact of Blast Furnace Slag ')

axes[2].plot(df['Fly Ash'],df['Strength'])
axes[2].set_ylabel('Strength')
axes[2].set_title('Impact of Fly Ash ')

axes[3].plot(df['Water'],df['Strength'])
axes[3].set_ylabel('Strength')
axes[3].set_title('Impact of water')

axes[4].plot(df['Superplasticizer'],df['Strength'])
axes[4].set_ylabel('Strength')
axes[4].set_title('Impact of Superplasticizer')

axes[5].plot(df['Coarse Aggregate'],df['Strength'])
axes[5].set_ylabel('Strength')
axes[5].set_title('Impact of Coarse Aggregate')

axes[6].plot(df['Fine Aggregate'],df['Strength'])
axes[6].set_ylabel('Strength')
axes[6].set_title('Impact of Fine Aggregate')

axes[7].plot(df['Age'],df['Strength'])
axes[7].set_ylabel('Strength')
axes[7].set_title('Impact of Age')

plt.tight_layout()

# %%
X = df.iloc[ : ,0:7].values
y = df.iloc[ : , -1].values

# %%
X
# Out:
# array([[ 540. ,    0. ,    0. , ...,    2.5, 1040. ,  676. ],
#        [ 540. ,    0. ,    0. , ...,    2.5, 1055. ,  676. ],
#        [ 332.5,  142.5,    0. , ...,    0. ,  932. ,  594. ],
#        ...,
#        [ 148.5,  139.4,  108.6, ...,    6.1,  892.4,  780. ],
#        [ 159.1,  186.7,    0. , ...,   11.3,  989.6,  788.9],
#        [ 260.9,  100.5,   78.3, ...,    8.6,  864.5,  761.5]])

# %%
y
# Out:
# array([79.99, 61.89, 40.27, ..., 23.7 , 32.77, 32.4 ])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (824, 7)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -12.730973460979477

# %%
model.coef_
# Out:
# array([ 0.11131572,  0.08948337,  0.06441823, -0.09497334,  0.36852103,
#         0.01778693,  0.00631195])

# %%
model.score(X_train,y_train)
# Out:
# 0.44661366737777597

# %%
test_predict=model.predict(X_test)

# %%
test_predict
# Out:
# array([47.81174086, 20.13887783, 54.73208767, 53.10232077, 29.19757749,
#        58.28075976, 48.68578267, 29.20967497, 55.94722654, 27.89187485,
#        21.05801663, 31.04907209, 27.94780767, 39.34056225, 51.92503363,
#        54.73571153, 36.00090601, 26.16049802, 54.82864975, 35.74690144,
#        49.57495879, 19.40345915, 33.47693815, 54.82864975, 29.82130465,
#        27.32759821, 69.2040374 , 28.51682796, 54.73571153, 41.14416849,
#        22.55423088, 34.28539562, 21.49435684, 27.06224541, 31.2084265 ,
#        20.92057933, 58.28075976, 29.09723335, 30.62273805, 26.07131387,
#        56.9438146 , 28.44268895, 29.97923354, 35.11216589, 54.73465444,
#        56.34805218, 36.96930621, 51.63934056, 37.77975283, 26.23261598,
#        38.50983151, 24.08811901, 27.87376959, 27.94780767, 35.11216589,
#        51.12582466, 35.58590393, 54.25663419, 56.34805218, 34.36701687,
#        35.4140374 , 24.51184583, 49.21666948, 55.4272125 , 25.60229203,
# ...

# %%
test_res= y_test-test_predict
test_res
# Out:
# array([-2.17517409e+01, -9.78887783e+00,  2.45679123e+01,  2.18876792e+01,
#        -1.95075775e+01, -1.11807598e+01,  1.03142173e+01, -6.48967497e+00,
#         5.94277346e+00,  2.42281252e+01, -3.51801663e+00,  1.71009279e+01,
#         1.03821923e+01, -2.21405623e+01,  4.90496637e+00,  5.14288470e-01,
#        -2.64090601e+00,  8.51950198e+00, -2.21864975e+00,  4.19309856e+00,
#         1.18850412e+01,  8.22654085e+00, -5.76938151e-01, -1.31886497e+01,
#        -1.22813047e+01, -4.77598213e-01, -2.30403740e+00, -7.45682796e+00,
#         6.33428847e+00,  2.58058315e+01, -1.68423088e+00,  1.45046044e+01,
#         2.55564316e+00,  2.07477546e+01, -1.00484265e+01, -1.39805793e+01,
#        -2.96807598e+01, -2.78723335e+00,  3.32726195e+00, -3.51313871e-01,
#        -1.91438146e+01,  6.72731105e+00,  2.26076646e+00,  2.69783411e+00,
#         2.49534556e+00, -2.29480522e+01, -6.82930621e+00, -1.78393406e+01,
# ...

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error,r2_score

# %%
MAE = mean_absolute_error (y_test,test_predict)
MAE
# Out:
# 9.645185684831578

# %%
MSE= mean_squared_error(y_test,test_predict)
MSE
# Out:
# 145.81854161786907

# %%
RMSE= np.sqrt(MSE)
RMSE
# Out:
# 12.075534837756424

# %%
r2_score(y_test,test_predict)
# Out:
# 0.44635606562733987

# %%
sns.displot(test_res,bins=20,kde=True)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter= PolynomialFeatures(degree=2,include_bias=False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
polynomial_converter.transform(X)
# Out:
# array([[5.4000000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0816000e+06,
#         7.0304000e+05, 4.5697600e+05],
#        [5.4000000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.1130250e+06,
#         7.1318000e+05, 4.5697600e+05],
#        [3.3250000e+02, 1.4250000e+02, 0.0000000e+00, ..., 8.6862400e+05,
#         5.5360800e+05, 3.5283600e+05],
#        ...,
#        [1.4850000e+02, 1.3940000e+02, 1.0860000e+02, ..., 7.9637776e+05,
#         6.9607200e+05, 6.0840000e+05],
#        [1.5910000e+02, 1.8670000e+02, 0.0000000e+00, ..., 9.7930816e+05,
#         7.8069544e+05, 6.2236321e+05],
#        [2.6090000e+02, 1.0050000e+02, 7.8300000e+01, ..., 7.4736025e+05,
#         6.5831675e+05, 5.7988225e+05]])

# %%
poly_features= polynomial_converter.fit_transform(X)

# %%
poly_features.shape
# Out:
# (1030, 35)

# %%
X_train,X_test,y_train,y_test= train_test_split(poly_features,y,test_size=0.8,random_state=0)

# %%
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predict=model.predict(X_test)

# %%
MSE= mean_squared_error(y_test,test_predict)
MSE
# Out:
# 180.85574223780907

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 13.448261680894266

# %%
train_rmse_errors = []

test_rmse_errors = []

for d in range(1,10):
    polynomial_converter = PolynomialFeatures(degree= d,include_bias=False)

    poly_features = polynomial_converter.fit_transform(X)

    X_train,X_test,y_train,y_test=train_test_split(poly_features,y,test_size=0.2,random_state=0)

    model=LinearRegression(fit_intercept=True)
    model.fit(X_train,y_train)

    train_pred=model.predict(X_train)
    test_pred=model.predict(X_test)

    train_RMSE= np.sqrt(mean_squared_error(y_train,train_pred))

    test_RMSE= np.sqrt(mean_squared_error(y_test,test_pred))

    train_rmse_errors.append(train_RMSE)
    test_rmse_errors.append(test_RMSE)

# %%
train_rmse_errors
# Out:
# [12.498140358256471,
#  11.424672411552624,
#  10.357596366971412,
#  9.739443254857282,
#  9.661067563610919,
#  9.661067562458307,
#  9.996114117494386,
#  9.661067602745018,
#  9.661159950185109]

# %%
test_rmse_errors
# Out:
# [12.075534837756424,
#  11.69449318886872,
#  12.448954791420395,
#  170.23383277096713,
#  68679.28551408197,
#  17410.266964335413,
#  13606922.809168497,
#  129936.76911854463,
#  7725681.522021309]

# %%
plt.plot(range(1,10),train_rmse_errors[:10],label="Train")
plt.plot(range(1,10),test_rmse_errors[:10],label="Test")
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.legend()

# %%
final_model=LinearRegression()

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
Concrete_strength= "Finalised_model.sav"

# %%
import joblib
from joblib import dump,load

# %%
joblib.dump(final_model,Concrete_strength)
# Out:
# ['Finalised_model.sav']
